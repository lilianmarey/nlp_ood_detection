# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import mahalanobis, cdist

import plotly.express as px
import pandas as pd

from aiirw import AI_IRW

from tqdm import tqdm

# %%
df = pd.read_csv('data/train_latent.csv')
df_in = pd.read_csv('data/in_latent.csv')
df_out = pd.read_csv('data/out_latent.csv')

# %%
def MahaDist(X, distrib):
    m = np.mean(distrib, axis=0).reshape(1, 768)
    VI= np.linalg.inv(np.cov(distrib.T))
    return cdist(XA = X, XB = m, metric = 'mahalanobis', VI=VI)

# %%
def process_latent_df(df):
    X = np.array(df.T)
    softmax_scores = X[:, -1]
    preds = X[:, -2]
    X = X[:, :-2]
    X = X.reshape((X.shape[0], 768, 12))
    X = np.mean(X, axis = 2)
    return X, softmax_scores, preds

# %%
X_out, softmax_out, preds_out = process_latent_df(df_out)
X_in, softmax_in, preds_in = process_latent_df(df_in)
X, softmax, preds = process_latent_df(df)

# %%
maha_in = np.concatenate([MahaDist(X_in[preds_in == 0], X[preds == 0]), MahaDist(X_in[preds_in == 1], X[preds == 1])])
maha_out = np.concatenate([MahaDist(X_out[preds_out == 0], X[preds == 0]), MahaDist(X_out[preds_out == 1], X[preds == 1])])

# %%
IRW_in = np.concatenate([AI_IRW(X=X[preds == 0], AI=True, X_test=X_in[preds_in == 0], n_dirs=1000), AI_IRW(X=X[preds == 1], AI=True, X_test=X_in[preds_in == 1], n_dirs=1000)])
IRW_out = np.concatenate([AI_IRW(X=X[preds == 0], AI=True, X_test=X_out[preds_out == 0], n_dirs=1000), AI_IRW(X=X[preds == 1], AI=True, X_test=X_out[preds_out == 1], n_dirs=1000)])

# %%
sim_df = pd.DataFrame(np.concatenate([maha_in, maha_out]), columns=['Maha'])
sim_df['origin'] = ['in'] * len(maha_in) + ['out'] * len(maha_out)
sim_df['IRW'] = -np.concatenate([IRW_in, IRW_out])

# %%
px.histogram(sim_df, x = 'Maha', color = 'origin', template = 'none', title = 'Maha').show()
px.histogram(sim_df, x = 'IRW', color = 'origin', template = 'none', title = 'IRW').show()
# Out:
# <div>                            <div id="59628c2f-8985-4a4c-b21b-2d4316da9daf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59628c2f-8985-4a4c-b21b-2d4316da9daf")) {                    Plotly.newPlot(                        "59628c2f-8985-4a4c-b21b-2d4316da9daf",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"origin=in<br>Maha=%{x}<br>count=%{y}<extra></extra>","legendgroup":"in","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"in","offsetgroup":"in","orientation":"v","showlegend":true,"x":[24.8065555556909,31.319258276165915,26.164290933068333,26.842678704369867,29.73486416682451,32.78385854211103,27.711676122639826,27.109271348675957,23.682139001036077,42.03248846027408,24.71480100215174,27.51045203327144,27.02931620687464,31.544605767574218,29.435771875101715,26.907619929159694,24.907759688526383,23.13360197241455,29.272784742410792,24.132551144373306,26.11739905212002,30.90318335909695,23.406904636432937,25.944462802193776,39.85703772703865,31.84176478313815,27.547323661319044,25.029813686773714,25.16595367943072,37.53284403037469,26.88605861741051,29.907556223097735,27.304018509236354,51.313228247291626,23.62484919083138,53.467553152155524,31.927932634407007,28.429361323584505,51.99334623446578,28.42859066547768,29.99196862342255,33.05845866296606,29.356086258552104,29.98430000180514,44.25750983350794,25.398983024337706,25.132882426036904,20.194565549487322,28.212167588768423,38.47443743990641,43.686785994877894,24.592217963431683,29.262440798758565,22.060485791589457,34
.1965341579983132,-0.1862472120700965,-0.2615484022116015,-0.2385136350857464,-0.2734506606691032,-0.2119567050885578,-0.224572954737138,-0.23805229125667696,-0.2884058663667885,-0.24844794302314685,-0.2729116296504545,-0.22689269984068972,-0.24923324899259677,-0.21013316465186016,-0.23639893168400336,-0.25131655889794774,-0.2683058757379814,-0.24982700777809014,-0.24746040670977412,-0.22804873020335487,-0.28035198200730954,-0.2451822697029332,-0.22428985099803203,-0.23118629931590293,-0.2471881735544935,-0.2395754849592353,-0.26075335020148066,-0.24739387123980885,-0.2360681285727673,-0.23308340361728047,-0.22701555618030175,-0.26733745665823266,-0.22157529753537625,-0.2523007215818574,-0.27469637334832725,-0.25321000843407365,-0.24803542310936183,-0.25037194264829915,-0.2763458907318901,-0.277245525255365,-0.2557362946303064,-0.2631467528816418,-0.2186334926436135,-0.24105707056508294,-0.1958840783431731,-0.2246961859244682,-0.27696841907974884,-0.21860715959141597,-0.25988417205510256,-0.28777218629931595,-0.26986617936463314,-0.2417796832536782,-0.1993055008902633,-0.22308762065410928,-0.20050098397526006,-0.2423348327242058,-0.23323671633398932,-0.28234036172804794,-0.2649597975822322,-0.22964867397619715,-0.2638934495361259,-0.27619970012182554,-0.2315818573704433,-0.23647961765532752,-0.2522130072158186,-0.25006344297629085,-0.24070490113391435,-0.24465701433792522,-0.25937484771811453,-0.24260631618405024,-0.17666947802455252,-0.2546852216287134,-0.2605923531065505,-0.24901855496204667,-0.2430118077031206,-0.24493993065317216,-0.25504910505107303,-0.2672654858963546,-0.2693736294630306,-0.16331374754006187,-0.2457803392371849,-0.2538565270358917,-0.2580665354699653,-0.16739330896823165,-0.26610402024177676,-0.209091650267079,-0.24483384874894573,-0.2580514478493112,-0.22596214038047044,-0.2540173367069628,-0.15783028769562366,-0.263620091837691,-0.20263958391903286,-0.24417205510261458,-0.20769421797394808,-0.3058869834129885,-0.18495539312154438,-0.15194161746790366,-0.2554252647362009,-0.25639396495173833,-0.22363789710430138,-0.22589794770874333,-0.2791617467903664,-0.23140043107487582,-0.19589682316558898,-0.22365129791022398,-0.22445047324524411,-0.2432763564 ...

# %% [markdown]
# ### Métriques de perf du classifier

# %%
def error_threshold(in_distances, out_distances, threshold):
    err = len([i for i in in_distances if i > threshold]) + len([i for i in out_distances if i <= threshold])
    return err / (len(in_distances) + len(out_distances))

# %%
def minimize_error(in_distances, out_distances, threshold_range):
    errors = [error_threshold(in_distances, out_distances, threshold) for threshold in tqdm(threshold_range)]
    return np.min(errors), threshold_range[np.argmin(errors)]

# %%
score_maha = minimize_error(
                (sim_df[sim_df['origin'] == 'in']['Maha']),
                (sim_df[sim_df['origin'] == 'out']['Maha']),
                np.linspace(0, 100, 10000)
                        )


score_IRW = minimize_error(
                (sim_df[sim_df['origin'] == 'in']['IRW']),
                (sim_df[sim_df['origin'] == 'out']['IRW']),
                np.linspace(-.3, -.05, 10000)
                        )
# Out:
# 100%|██████████| 10000/10000 [00:04<00:00, 2028.01it/s]
# 100%|██████████| 10000/10000 [00:05<00:00, 1962.97it/s]

# %%
score_maha
# Out:
# (0.08993816750983699, 36.71367136713672)

# %%
score_IRW
# Out:
# (0.09021922428330523, -0.19843984398439843)
